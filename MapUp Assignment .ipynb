# %% [markdown]
# # Python Test - 1
# <hr>
#
# ### Question 1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset-1.csv')
df.head()
# Out:
#    id_1  id_2  route   moto    car     rv   bus  truck
# 0   829   827      1   2.05   4.14   4.14  10.1   15.2
# 1   829   821      4   6.63  13.26  13.26  32.4   48.5
# 2   829   804      7  14.41  28.92  28.92  64.7   97.0
# 3   829   822      6   5.90  11.81  11.81  28.8   43.2
# 4   829   826      9   2.87   5.81   5.81  14.2   21.2

# %%
df.isnull().sum()
# Out:
# id_1     0
# id_2     0
# route    0
# moto     0
# car      0
# rv       0
# bus      0
# truck    0
# dtype: int64

# %%
pd.DataFrame(df)
# Out:
#      id_1  id_2  route   moto    car     rv   bus  truck
# 0     829   827      1   2.05   4.14   4.14  10.1   15.2
# 1     829   821      4   6.63  13.26  13.26  32.4   48.5
# 2     829   804      7  14.41  28.92  28.92  64.7   97.0
# 3     829   822      6   5.90  11.81  11.81  28.8   43.2
# 4     829   826      9   2.87   5.81   5.81  14.2   21.2
# ..    ...   ...    ...    ...    ...    ...   ...    ...
# 336   803   802      3   1.70   3.40   3.40   6.9   10.3
# 337   803   805      4   3.00   6.00   6.00  12.0   17.9
# 338   803   825      3  11.59  23.28  23.28  50.1   75.2
# 339   803   806      9   3.80   7.70   7.70  15.3   23.0
# 340   803   830      1  16.18  32.47  32.47  72.6  108.8
#
# [341 rows x 8 columns]

# %%
def generate_car_matrix(df):
    df = df.pivot_table(index='id_1', columns='id_2', values='car')
    
    return df

# %%
df_new = generate_car_matrix(df)


print(df_new)
# Out:
# id_2    801    802    803    804    805    806    807    808    809    821  \
# id_1
# 801     NaN   2.80   6.00   7.70  11.70  13.40  16.90  19.60  21.00  23.52
# 802    2.80    NaN   3.40   5.20   9.20  10.90  14.30  17.10  18.50  20.92
# 803    6.00   3.40    NaN   2.00   6.00   7.70  11.10  13.90  15.30  17.72
# 804    7.70   5.20   2.00    NaN   4.40   6.10   9.50  12.30  13.70  16.12
# 805   11.70   9.20   6.00   4.40    NaN   2.00   5.40   8.20   9.60  12.02
# 806   13.40  10.90   7.70   6.10   2.00    NaN   3.80   6.60   8.00  10.42
# 807   16.90  14.30  11.10   9.50   5.40   3.80    NaN   2.90   4.30   6.82
# 808   19.60  17.10  13.90  12.30   8.20   6.60   2.90    NaN   1.70   4.12
# 809   21.00  18.50  15.30  13.70   9.60   8.00   4.30   1.70    NaN   2.92
# 821   23.52  20.92  17.72  16.12  12.02  10.42   6.82   4.12   2.92    NaN
# 822   24.67  22.07  18.87  17.27  13.17  11.57   7.97   5.27   4.07   1.80
# ...

# %%
df_new = df_new.fillna(0)

# %%
df_new.head()
# Out:
# id_2   801  802  803  804   805   806   807   808   809    821    822    823  \
# id_1
# 801    0.0  2.8  6.0  7.7  11.7  13.4  16.9  19.6  21.0  23.52  24.67  26.53
# 802    2.8  0.0  3.4  5.2   9.2  10.9  14.3  17.1  18.5  20.92  22.07  23.93
# 803    6.0  3.4  0.0  2.0   6.0   7.7  11.1  13.9  15.3  17.72  18.87  20.73
# 804    7.7  5.2  2.0  0.0   4.4   6.1   9.5  12.3  13.7  16.12  17.27  19.13
# 805   11.7  9.2  6.0  4.4   0.0   2.0   5.4   8.2   9.6  12.02  13.17  15.03
#
# id_2    824    825    826    827    829    830    831
# id_1
# 801   27.92  29.08  30.87  32.53  36.32  38.27  39.24
# 802   25.32  26.48  28.27  29.93  33.72  35.67  36.64
# 803   22.12  23.28  25.07  26.73  30.52  32.47  33.44
# 804   20.52  21.68  23.47  25.13  28.92  30.87  31.84
# 805   16.42  17.58  19.37  21.03  24.82  26.77  27.74

# %% [markdown]
# ### Question 2
# <hr>

# %%
data = pd.read_csv('dataset-1.csv')
data.head()
# Out:
#    id_1  id_2  route   moto    car     rv   bus  truck
# 0   829   827      1   2.05   4.14   4.14  10.1   15.2
# 1   829   821      4   6.63  13.26  13.26  32.4   48.5
# 2   829   804      7  14.41  28.92  28.92  64.7   97.0
# 3   829   822      6   5.90  11.81  11.81  28.8   43.2
# 4   829   826      9   2.87   5.81   5.81  14.2   21.2

# %%
pd.DataFrame(data)
# Out:
#      id_1  id_2  route   moto    car     rv   bus  truck
# 0     829   827      1   2.05   4.14   4.14  10.1   15.2
# 1     829   821      4   6.63  13.26  13.26  32.4   48.5
# 2     829   804      7  14.41  28.92  28.92  64.7   97.0
# 3     829   822      6   5.90  11.81  11.81  28.8   43.2
# 4     829   826      9   2.87   5.81   5.81  14.2   21.2
# ..    ...   ...    ...    ...    ...    ...   ...    ...
# 336   803   802      3   1.70   3.40   3.40   6.9   10.3
# 337   803   805      4   3.00   6.00   6.00  12.0   17.9
# 338   803   825      3  11.59  23.28  23.28  50.1   75.2
# 339   803   806      9   3.80   7.70   7.70  15.3   23.0
# 340   803   830      1  16.18  32.47  32.47  72.6  108.8
#
# [341 rows x 8 columns]

# %%
def get_type_count(data):
    data['car_type'] = data['car'].apply(lambda x:'Low' if x <=15 else 'Medium' if x<=25 else 'High')

#Finding type count 
    count_types=data['car_type'].value_counts().to_dict()

#Sorting the new dict

    count_types_sorted = dict(sorted(count_types.items())) 
    
     
    return count_types_sorted

# %%
count_types= get_type_count(data)


print(count_types)
# Out:
# {'High': 56, 'Low': 196, 'Medium': 89}

# %% [markdown]
# ### Question 3
# <hr>

# %%
def get_bus_indexes(data):
    
#To find mean of bus data
    mean = data['bus'].mean()
    
#Findind the indices

    bus_indexes = data[data['bus'].apply(lambda x: x > 2 * mean)].index.tolist()
    
#Sorting the data in asc 
    
    sorted_bus_indexes=bus_indexes.sort()
    return sorted_bus_indexes

# %%
bus_indexes = get_bus_indexes(data)

print(bus_indexes)
# Out:
# None

# %% [markdown]
# ### Question 4
# <hr>

# %%
def filter_routes(data):
#Calculate average truck value for each route
    avg_truck_per_route = df.groupby('route')['truck'].mean()

#Filter routes with average truck value greater than 7
    filtered_routes = avg_truck_per_route[avg_truck_per_route > 7]

#Sorting the data 
    sorted_routes = filtered_routes.sort_values()
    return sorted_routes

# %%
routes = filter_routes(data)

print(routes)
# Out:
# route
# 10    41.400000
# 2     41.403125
# 5     43.327778
# 8     46.128571
# 6     47.952500
# 1     49.164103
# 3     50.075000
# 4     51.096774
# 7     52.525862
# 9     54.531429
# Name: truck, dtype: float64

# %% [markdown]
# ### Question 5
# <hr>

# %%
def multiply_matrix(df_new):
    data5 = df_new.applymap(lambda x: round(x * (0.75 if x > 20 else 1.25), 1))


    return data5

# %%
multiplied_matrix = multiply_matrix(df_new)

print(multiplied_matrix)
# Out:
# id_2   801   802   803   804   805   806   807   808   809   821   822   823  \
# id_1
# 801    0.0   3.5   7.5   9.6  14.6  16.8  21.1  24.5  15.8  17.6  18.5  19.9
# 802    3.5   0.0   4.2   6.5  11.5  13.6  17.9  21.4  23.1  15.7  16.6  17.9
# 803    7.5   4.2   0.0   2.5   7.5   9.6  13.9  17.4  19.1  22.1  23.6  15.5
# 804    9.6   6.5   2.5   0.0   5.5   7.6  11.9  15.4  17.1  20.2  21.6  23.9
# 805   14.6  11.5   7.5   5.5   0.0   2.5   6.8  10.2  12.0  15.0  16.5  18.8
# 806   16.8  13.6   9.6   7.6   2.5   0.0   4.8   8.2  10.0  13.0  14.5  16.8
# 807   21.1  17.9  13.9  11.9   6.8   4.8   0.0   3.6   5.4   8.5  10.0  12.3
# 808   24.5  21.4  17.4  15.4  10.2   8.2   3.6   0.0   2.1   5.2   6.6   8.9
# 809   15.8  23.1  19.1  17.1  12.0  10.0   5.4   2.1   0.0   3.6   5.1   7.4
# 821   17.6  15.7  22.1  20.2  15.0  13.0   8.5   5.2   3.6   0.0   2.2   4.6
# 822   18.5  16.6  23.6  21.6  16.5  14.5  10.0   6.6   5.1   2.2   0.0   2.8
# ...

# %% [markdown]
# ### Question 6

# %% [markdown]
# * The concept was completely new to me and I had to do my research before doing it. I had a clear idea about date,time function of pandas but I still tried and I guess I will figure it out as soon as I start doing more of this questions.

# %%
data6 = pd.read_csv('dataset-2.csv')
data6.head()
# Out:
#         id        name     id_2  startDay startTime     endDay   endTime  \
# 0  1040000  Montgomery       -1    Monday  05:00:00  Wednesday  10:00:00
# 1  1040010       Black       -1    Monday  10:00:00     Friday  15:00:00
# 2  1040020     Emerald       -1  Thursday  15:00:00     Friday  19:00:00
# 3  1040030       Foley       -1    Monday  19:00:00     Friday  23:59:59
# 4  1050000    Whittier  1050001  Saturday  00:00:00     Sunday  23:59:59
#
#    able2Hov2  able2Hov3  able3Hov2  able3Hov3  able5Hov2  able5Hov3  \
# 0        3.0        3.0       -1.0         -1          3          3
# 1        6.0        6.0       -1.0         -1          6          6
# 2        3.0        3.0       -1.0         -1          3          3
# 3        6.0        6.0       -1.0         -1          6          6
# 4        6.0        6.0        NaN         -1          6          6
#
#    able4Hov2  able4Hov3
# 0          3          3
# 1          6          6
# 2          3          3
# ...

# %% [markdown]
# ## Python Task 2
# <hr>
#
# ### Question 1

# %%
task2 = pd.read_csv('dataset-2.csv')

task2.head()
# Out:
#         id        name     id_2  startDay startTime     endDay   endTime  \
# 0  1040000  Montgomery       -1    Monday  05:00:00  Wednesday  10:00:00
# 1  1040010       Black       -1    Monday  10:00:00     Friday  15:00:00
# 2  1040020     Emerald       -1  Thursday  15:00:00     Friday  19:00:00
# 3  1040030       Foley       -1    Monday  19:00:00     Friday  23:59:59
# 4  1050000    Whittier  1050001  Saturday  00:00:00     Sunday  23:59:59
#
#    able2Hov2  able2Hov3  able3Hov2  able3Hov3  able5Hov2  able5Hov3  \
# 0        3.0        3.0       -1.0         -1          3          3
# 1        6.0        6.0       -1.0         -1          6          6
# 2        3.0        3.0       -1.0         -1          3          3
# 3        6.0        6.0       -1.0         -1          6          6
# 4        6.0        6.0        NaN         -1          6          6
#
#    able4Hov2  able4Hov3
# 0          3          3
# 1          6          6
# 2          3          3
# ...

# %%
task2.isnull().sum()
# Out:
# id              0
# name            0
# id_2            0
# startDay        0
# startTime       0
# endDay          0
# endTime         0
# able2Hov2    1806
# able2Hov3    1805
# able3Hov2    1805
# able3Hov3       0
# able5Hov2       0
# able5Hov3       0
# able4Hov2       0
# able4Hov3       0
# dtype: int64

# %%
task2.shape
# Out:
# (39514, 15)

# %%
task2['able2Hov3'].value_counts()
# Out:
# 6.0     13532
# 11.0    10175
# 3.0      7219
# 8.0      5427
# 5.0      1356
# Name: able2Hov3, dtype: int64

# %%
task2['able2Hov2'].value_counts()
# Out:
# 6.0     15337
# 11.0    11531
# 3.0      5413
# 8.0      4071
# 5.0      1356
# Name: able2Hov2, dtype: int64

# %%
task2['able3Hov2'].value_counts()
# Out:
# -1.0    20751
#  4.0    15602
#  5.0     1356
# Name: able3Hov2, dtype: int64
